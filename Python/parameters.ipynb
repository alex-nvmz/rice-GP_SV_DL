# %%
import os
import itertools

import numpy as np
import pandas as pd

# %%
# Generate parameter grid for the different analyses #####################################

# Expand grid function from dictionary of lists
def expand_grid(dict):
    rows = itertools.product(*dict.values())
    return pd.DataFrame.from_records(rows, columns = dict.keys())

# Load data source for grid
Y_df = pd.read_csv(os.path.join("data", "pheno_original.csv"))
parts = pd.read_csv(os.path.join("data", "partitions.csv"))

# Traits list
traits = Y_df.columns[[3, 9, 10, 12]].to_list()

# %%
# 1. top-markers-10k -------------------------------------------------------------------------
model_type = "top-markers-10k"

# 1.1. AroAdm ============================================================================
out_name = f"AroAdm_{model_type}.csv"

folds = ["AroAdm"]

grid_dict = {
    "model_type": [model_type],
    "architecture": ["MLP", "CNN"],
    "m_set": ["SNP", "all"],
    "traits": traits,
    "part": folds,
    "input_type": ["single-input"],
    "output_type": ["single-output"]
}

grid = expand_grid(grid_dict)
print(grid)

grid.to_csv(os.path.join("parameters", out_name), index = False)
# Out:
#          model_type architecture m_set                         traits    part  \
# 0   top-markers-10k          MLP   SNP    culm.diameter.1st.internode  AroAdm
# 1   top-markers-10k          MLP   SNP                leaf.senescence  AroAdm
# 2   top-markers-10k          MLP   SNP                   grain.weight  AroAdm
# 3   top-markers-10k          MLP   SNP  time.to.flowering.from.sowing  AroAdm
# 4   top-markers-10k          MLP   all    culm.diameter.1st.internode  AroAdm
# 5   top-markers-10k          MLP   all                leaf.senescence  AroAdm
# 6   top-markers-10k          MLP   all                   grain.weight  AroAdm
# 7   top-markers-10k          MLP   all  time.to.flowering.from.sowing  AroAdm
# 8   top-markers-10k          CNN   SNP    culm.diameter.1st.internode  AroAdm
# 9   top-markers-10k          CNN   SNP                leaf.senescence  AroAdm
# 10  top-markers-10k          CNN   SNP                   grain.weight  AroAdm
# 11  top-markers-10k          CNN   SNP  time.to.flowering.from.sowing  AroAdm
# 12  top-markers-10k          CNN   all    culm.diameter.1st.internode  AroAdm
# 13  top-markers-10k          CNN   all                leaf.senescence  AroAdm
# 14  top-markers-10k          CNN   all                   grain.weight  AroAdm
# 15  top-markers-10k          CNN   all  time.to.flowering.from.sowing  AroAdm
#
#       input_type    output_type
# 0   single-input  single-output
# 1   single-input  single-output
# 2   single-input  single-output
# 3   single-input  single-output
# 4   single-input  single-output
# 5   single-input  single-output
# 6   single-input  single-output
# 7   single-input  single-output
# 8   single-input  single-output
# 9   single-input  single-output
# 10  single-input  single-output
# 11  single-input  single-output
# 12  single-input  single-output
# 13  single-input  single-output
# 14  single-input  single-output
# 15  single-input  single-output

# %%
# 1.2. 10-fold-cv ========================================================================
out_name = f"10-fold-cv_{model_type}.csv"

folds = parts.columns.drop(["Accession", "AroAdm"]).to_list()

grid_dict = {
    "model_type": [model_type],
    "architecture": ["MLP", "CNN"],
    "m_set": ["SNP", "all"],
    "traits": traits,
    "part": folds,
    "input_type": ["single-input"],
    "output_type": ["single-output"]
}

grid = expand_grid(grid_dict)
print(grid)

grid.to_csv(os.path.join("parameters", out_name), index = False)
# Out:
#           model_type architecture m_set                         traits  \
# 0    top-markers-10k          MLP   SNP    culm.diameter.1st.internode
# 1    top-markers-10k          MLP   SNP    culm.diameter.1st.internode
# 2    top-markers-10k          MLP   SNP    culm.diameter.1st.internode
# 3    top-markers-10k          MLP   SNP    culm.diameter.1st.internode
# 4    top-markers-10k          MLP   SNP    culm.diameter.1st.internode
# ..               ...          ...   ...                            ...
# 155  top-markers-10k          CNN   all  time.to.flowering.from.sowing
# 156  top-markers-10k          CNN   all  time.to.flowering.from.sowing
# 157  top-markers-10k          CNN   all  time.to.flowering.from.sowing
# 158  top-markers-10k          CNN   all  time.to.flowering.from.sowing
# 159  top-markers-10k          CNN   all  time.to.flowering.from.sowing
#
#         part    input_type    output_type
# 0     Fold.1  single-input  single-output
# 1     Fold.2  single-input  single-output
# 2     Fold.3  single-input  single-output
# 3     Fold.4  single-input  single-output
# 4     Fold.5  single-input  single-output
# ..       ...           ...            ...
# 155   Fold.6  single-input  single-output
# 156   Fold.7  single-input  single-output
# 157   Fold.8  single-input  single-output
# 158   Fold.9  single-input  single-output
# 159  Fold.10  single-input  single-output
#
# [160 rows x 7 columns]

# %%
# 2. kerPC -------------------------------------------------------------------------------
model_type = "kerPC"

# 2.1. AroAdm ============================================================================
out_name = f"AroAdm_{model_type}.csv"

folds = ["AroAdm"]

grid_dict = {
    "model_type": [model_type],
    "architecture": ["MLP"],
    "m_set": ["SNP", "all"],
    "traits": traits,
    "part": folds,
    "input_type": ["single-input", "multi-input"],
    "output_type": ["single-output"]
}

grid = expand_grid(grid_dict)

# No multi-input with SNP kernel case
grid = grid[~ ((grid.input_type == "multi-input") & (grid.m_set == "SNP"))]
print(grid)

grid.to_csv(os.path.join("parameters", out_name), index = False)
# Out:
#    model_type architecture m_set                         traits    part  \
# 0       kerPC          MLP   SNP    culm.diameter.1st.internode  AroAdm
# 2       kerPC          MLP   SNP                leaf.senescence  AroAdm
# 4       kerPC          MLP   SNP                   grain.weight  AroAdm
# 6       kerPC          MLP   SNP  time.to.flowering.from.sowing  AroAdm
# 8       kerPC          MLP   all    culm.diameter.1st.internode  AroAdm
# 9       kerPC          MLP   all    culm.diameter.1st.internode  AroAdm
# 10      kerPC          MLP   all                leaf.senescence  AroAdm
# 11      kerPC          MLP   all                leaf.senescence  AroAdm
# 12      kerPC          MLP   all                   grain.weight  AroAdm
# 13      kerPC          MLP   all                   grain.weight  AroAdm
# 14      kerPC          MLP   all  time.to.flowering.from.sowing  AroAdm
# 15      kerPC          MLP   all  time.to.flowering.from.sowing  AroAdm
#
#       input_type    output_type
# 0   single-input  single-output
# 2   single-input  single-output
# 4   single-input  single-output
# 6   single-input  single-output
# 8   single-input  single-output
# 9    multi-input  single-output
# 10  single-input  single-output
# 11   multi-input  single-output
# 12  single-input  single-output
# 13   multi-input  single-output
# 14  single-input  single-output
# 15   multi-input  single-output

# %%
# 2.2. 10-fold-cv ========================================================================
out_name = f"10-fold-cv_{model_type}.csv"

folds = parts.columns.drop(["Accession", "AroAdm"]).to_list()

grid_dict = {
    "model_type": [model_type],
    "architecture": ["MLP"],
    "m_set": ["SNP", "all"],
    "traits": traits,
    "part": folds,
    "input_type": ["single-input", "multi-input"],
    "output_type": ["single-output"]
}

grid = expand_grid(grid_dict)

# No multi-input with SNP kernel case
grid = grid[~ ((grid.input_type == "multi-input") & (grid.m_set == "SNP"))]
print(grid)

grid.to_csv(os.path.join("parameters", out_name), index = False)
# Out:
#     model_type architecture m_set                         traits     part  \
# 0        kerPC          MLP   SNP    culm.diameter.1st.internode   Fold.1
# 2        kerPC          MLP   SNP    culm.diameter.1st.internode   Fold.2
# 4        kerPC          MLP   SNP    culm.diameter.1st.internode   Fold.3
# 6        kerPC          MLP   SNP    culm.diameter.1st.internode   Fold.4
# 8        kerPC          MLP   SNP    culm.diameter.1st.internode   Fold.5
# ..         ...          ...   ...                            ...      ...
# 155      kerPC          MLP   all  time.to.flowering.from.sowing   Fold.8
# 156      kerPC          MLP   all  time.to.flowering.from.sowing   Fold.9
# 157      kerPC          MLP   all  time.to.flowering.from.sowing   Fold.9
# 158      kerPC          MLP   all  time.to.flowering.from.sowing  Fold.10
# 159      kerPC          MLP   all  time.to.flowering.from.sowing  Fold.10
#
#        input_type    output_type
# 0    single-input  single-output
# 2    single-input  single-output
# 4    single-input  single-output
# 6    single-input  single-output
# 8    single-input  single-output
# ..            ...            ...
# 155   multi-input  single-output
# 156  single-input  single-output
# 157   multi-input  single-output
# 158  single-input  single-output
# 159   multi-input  single-output
#
# [120 rows x 7 columns]

# %%
# 3. multi-output ------------------------------------------------------------------------

target_dict = {
    "culm.diameter.1st.internode": "binary",
    "leaf.senescence": "binary",
    "grain.weight": "continuous",
    "time.to.flowering.from.sowing": "continuous"
}

# Lists of traits to predict jointly
trait_lists = []
# Combinations of 2 with same variable type (binary or continuous)
for comb in itertools.combinations(traits, 2):
    target_type_list = []
    for trait in comb:
        target_type_list.append(target_dict[trait])
    if all(x == target_type_list[0] for x in target_type_list):
        trait_lists.append(list(comb))
# All traits at the same time
trait_lists.append(traits)
        
print(trait_lists)
# Out:
# [['culm.diameter.1st.internode', 'leaf.senescence'], ['grain.weight', 'time.to.flowering.from.sowing'], ['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']]

# %%
# 3.1 top-markers-10k ========================================================================
model_type = "top-markers-10k"
output_type = "multi-output"
input_type = "multi-input"

# AroAdm #################################################################################
out_name = f"AroAdm_{model_type}_{input_type}_{output_type}.csv"

folds = ["AroAdm"]

grid_dict = {
    "model_type": [model_type],
    "architecture": ["MLP"],
    "m_set": ["SNP", "all"],
    "traits": trait_lists,
    "part": folds,
    "input_type": [input_type],
    "output_type": [output_type]
}

grid = expand_grid(grid_dict)
print(grid)

grid.to_csv(os.path.join("parameters", out_name), index = False)
# Out:
#         model_type architecture m_set  \
# 0  top-markers-10k          MLP   SNP
# 1  top-markers-10k          MLP   SNP
# 2  top-markers-10k          MLP   SNP
# 3  top-markers-10k          MLP   all
# 4  top-markers-10k          MLP   all
# 5  top-markers-10k          MLP   all
#
#                                               traits    part   input_type  \
# 0     [culm.diameter.1st.internode, leaf.senescence]  AroAdm  multi-input
# 1      [grain.weight, time.to.flowering.from.sowing]  AroAdm  multi-input
# 2  [culm.diameter.1st.internode, leaf.senescence,...  AroAdm  multi-input
# 3     [culm.diameter.1st.internode, leaf.senescence]  AroAdm  multi-input
# 4      [grain.weight, time.to.flowering.from.sowing]  AroAdm  multi-input
# 5  [culm.diameter.1st.internode, leaf.senescence,...  AroAdm  multi-input
#
#     output_type
# 0  multi-output
# 1  multi-output
# 2  multi-output
# 3  multi-output
# 4  multi-output
# 5  multi-output

# %%
# 10-fold-cv #############################################################################
out_name = f"10-fold-cv_{model_type}_{input_type}_{output_type}.csv"

folds = parts.columns.drop(["Accession", "AroAdm"]).to_list()

grid_dict = {
    "model_type": [model_type],
    "architecture": ["MLP"],
    "m_set": ["SNP", "all"],
    "traits": trait_lists,
    "part": folds,
    "input_type": [input_type],
    "output_type": [output_type]
}

grid = expand_grid(grid_dict)
print(grid)

grid.to_csv(os.path.join("parameters", out_name), index = False)
# Out:
#          model_type architecture m_set  \
# 0   top-markers-10k          MLP   SNP
# 1   top-markers-10k          MLP   SNP
# 2   top-markers-10k          MLP   SNP
# 3   top-markers-10k          MLP   SNP
# 4   top-markers-10k          MLP   SNP
# 5   top-markers-10k          MLP   SNP
# 6   top-markers-10k          MLP   SNP
# 7   top-markers-10k          MLP   SNP
# 8   top-markers-10k          MLP   SNP
# 9   top-markers-10k          MLP   SNP
# 10  top-markers-10k          MLP   SNP
# 11  top-markers-10k          MLP   SNP
# 12  top-markers-10k          MLP   SNP
# 13  top-markers-10k          MLP   SNP
# 14  top-markers-10k          MLP   SNP
# 15  top-markers-10k          MLP   SNP
# 16  top-markers-10k          MLP   SNP
# 17  top-markers-10k          MLP   SNP
# 18  top-markers-10k          MLP   SNP
# 19  top-markers-10k          MLP   SNP
# 20  top-markers-10k          MLP   SNP
# 21  top-markers-10k          MLP   SNP
# 22  top-markers-10k          MLP   SNP
# 23  top-markers-10k          MLP   SNP
# 24  top-markers-10k          MLP   SNP
# 25  top-markers-10k          MLP   SNP
# 26  top-markers-10k          MLP   SNP
# 27  top-markers-10k          MLP   SNP
# 28  top-markers-10k          MLP   SNP
# 29  top-markers-10k          MLP   SNP
# 30  top-markers-10k          MLP   all
# 31  top-markers-10k          MLP   all
# 32  top-markers-10k          MLP   all
# 33  top-markers-10k          MLP   all
# 34  top-markers-10k          MLP   all
# 35  top-markers-10k          MLP   all
# 36  top-markers-10k          MLP   all
# 37  top-markers-10k          MLP   all
# 38  top-markers-10k          MLP   all
# 39  top-markers-10k          MLP   all
# 40  top-markers-10k          MLP   all
# 41  top-markers-10k          MLP   all
# 42  top-markers-10k          MLP   all
# 43  top-markers-10k          MLP   all
# 44  top-markers-10k          MLP   all
# 45  top-markers-10k          MLP   all
# 46  top-markers-10k          MLP   all
# 47  top-markers-10k          MLP   all
# 48  top-markers-10k          MLP   all
# 49  top-markers-10k          MLP   all
# 50  top-markers-10k          MLP   all
# 51  top-markers-10k          MLP   all
# 52  top-markers-10k          MLP   all
# 53  top-markers-10k          MLP   all
# 54  top-markers-10k          MLP   all
# 55  top-markers-10k          MLP   all
# 56  top-markers-10k          MLP   all
# 57  top-markers-10k          MLP   all
# 58  top-markers-10k          MLP   all
# 59  top-markers-10k          MLP   all
#
#                                                traits     part   input_type  \
# 0      [culm.diameter.1st.internode, leaf.senescence]   Fold.1  multi-input
# 1      [culm.diameter.1st.internode, leaf.senescence]   Fold.2  multi-input
# 2      [culm.diameter.1st.internode, leaf.senescence]   Fold.3  multi-input
# 3      [culm.diameter.1st.internode, leaf.senescence]   Fold.4  multi-input
# 4      [culm.diameter.1st.internode, leaf.senescence]   Fold.5  multi-input
# 5      [culm.diameter.1st.internode, leaf.senescence]   Fold.6  multi-input
# 6      [culm.diameter.1st.internode, leaf.senescence]   Fold.7  multi-input
# 7      [culm.diameter.1st.internode, leaf.senescence]   Fold.8  multi-input
# 8      [culm.diameter.1st.internode, leaf.senescence]   Fold.9  multi-input
# 9      [culm.diameter.1st.internode, leaf.senescence]  Fold.10  multi-input
# 10      [grain.weight, time.to.flowering.from.sowing]   Fold.1  multi-input
# 11      [grain.weight, time.to.flowering.from.sowing]   Fold.2  multi-input
# 12      [grain.weight, time.to.flowering.from.sowing]   Fold.3  multi-input
# 13      [grain.weight, time.to.flowering.from.sowing]   Fold.4  multi-input
# 14      [grain.weight, time.to.flowering.from.sowing]   Fold.5  multi-input
# 15      [grain.weight, time.to.flowering.from.sowing]   Fold.6  multi-input
# 16      [grain.weight, time.to.flowering.from.sowing]   Fold.7  multi-input
# 17      [grain.weight, time.to.flowering.from.sowing]   Fold.8  multi-input
# 18      [grain.weight, time.to.flowering.from.sowing]   Fold.9  multi-input
# 19      [grain.weight, time.to.flowering.from.sowing]  Fold.10  multi-input
# 20  [culm.diameter.1st.internode, leaf.senescence,...   Fold.1  multi-input
# 21  [culm.diameter.1st.internode, leaf.senescence,...   Fold.2  multi-input
# 22  [culm.diameter.1st.internode, leaf.senescence,...   Fold.3  multi-input
# 23  [culm.diameter.1st.internode, leaf.senescence,...   Fold.4  multi-input
# 24  [culm.diameter.1st.internode, leaf.senescence,...   Fold.5  multi-input
# 25  [culm.diameter.1st.internode, leaf.senescence,...   Fold.6  multi-input
# 26  [culm.diameter.1st.internode, leaf.senescence,...   Fold.7  multi-input
# 27  [culm.diameter.1st.internode, leaf.senescence,...   Fold.8  multi-input
# 28  [culm.diameter.1st.internode, leaf.senescence,...   Fold.9  multi-input
# 29  [culm.diameter.1st.internode, leaf.senescence,...  Fold.10  multi-input
# 30     [culm.diameter.1st.internode, leaf.senescence]   Fold.1  multi-input
# 31     [culm.diameter.1st.internode, leaf.senescence]   Fold.2  multi-input
# 32     [culm.diameter.1st.internode, leaf.senescence]   Fold.3  multi-input
# 33     [culm.diameter.1st.internode, leaf.senescence]   Fold.4  multi-input
# 34     [culm.diameter.1st.internode, leaf.senescence]   Fold.5  multi-input
# 35     [culm.diameter.1st.internode, leaf.senescence]   Fold.6  multi-input
# 36     [culm.diameter.1st.internode, leaf.senescence]   Fold.7  multi-input
# 37     [culm.diameter.1st.internode, leaf.senescence]   Fold.8  multi-input
# 38     [culm.diameter.1st.internode, leaf.senescence]   Fold.9  multi-input
# 39     [culm.diameter.1st.internode, leaf.senescence]  Fold.10  multi-input
# 40      [grain.weight, time.to.flowering.from.sowing]   Fold.1  multi-input
# 41      [grain.weight, time.to.flowering.from.sowing]   Fold.2  multi-input
# 42      [grain.weight, time.to.flowering.from.sowing]   Fold.3  multi-input
# 43      [grain.weight, time.to.flowering.from.sowing]   Fold.4  multi-input
# 44      [grain.weight, time.to.flowering.from.sowing]   Fold.5  multi-input
# 45      [grain.weight, time.to.flowering.from.sowing]   Fold.6  multi-input
# 46      [grain.weight, time.to.flowering.from.sowing]   Fold.7  multi-input
# 47      [grain.weight, time.to.flowering.from.sowing]   Fold.8  multi-input
# 48      [grain.weight, time.to.flowering.from.sowing]   Fold.9  multi-input
# 49      [grain.weight, time.to.flowering.from.sowing]  Fold.10  multi-input
# 50  [culm.diameter.1st.internode, leaf.senescence,...   Fold.1  multi-input
# 51  [culm.diameter.1st.internode, leaf.senescence,...   Fold.2  multi-input
# 52  [culm.diameter.1st.internode, leaf.senescence,...   Fold.3  multi-input
# 53  [culm.diameter.1st.internode, leaf.senescence,...   Fold.4  multi-input
# 54  [culm.diameter.1st.internode, leaf.senescence,...   Fold.5  multi-input
# 55  [culm.diameter.1st.internode, leaf.senescence,...   Fold.6  multi-input
# 56  [culm.diameter.1st.internode, leaf.senescence,...   Fold.7  multi-input
# 57  [culm.diameter.1st.internode, leaf.senescence,...   Fold.8  multi-input
# 58  [culm.diameter.1st.internode, leaf.senescence,...   Fold.9  multi-input
# 59  [culm.diameter.1st.internode, leaf.senescence,...  Fold.10  multi-input
#
#      output_type
# 0   multi-output
# 1   multi-output
# 2   multi-output
# 3   multi-output
# 4   multi-output
# 5   multi-output
# 6   multi-output
# 7   multi-output
# 8   multi-output
# 9   multi-output
# 10  multi-output
# 11  multi-output
# 12  multi-output
# 13  multi-output
# 14  multi-output
# 15  multi-output
# 16  multi-output
# 17  multi-output
# 18  multi-output
# 19  multi-output
# 20  multi-output
# 21  multi-output
# 22  multi-output
# 23  multi-output
# 24  multi-output
# 25  multi-output
# 26  multi-output
# 27  multi-output
# 28  multi-output
# 29  multi-output
# 30  multi-output
# 31  multi-output
# 32  multi-output
# 33  multi-output
# 34  multi-output
# 35  multi-output
# 36  multi-output
# 37  multi-output
# 38  multi-output
# 39  multi-output
# 40  multi-output
# 41  multi-output
# 42  multi-output
# 43  multi-output
# 44  multi-output
# 45  multi-output
# 46  multi-output
# 47  multi-output
# 48  multi-output
# 49  multi-output
# 50  multi-output
# 51  multi-output
# 52  multi-output
# 53  multi-output
# 54  multi-output
# 55  multi-output
# 56  multi-output
# 57  multi-output
# 58  multi-output
# 59  multi-output

# %%
# 3.2 kerPC ==============================================================================
model_type = "kerPC"
output_type = "multi-output"

# AroAdm #################################################################################
out_name = f"AroAdm_{model_type}_{output_type}.csv"

folds = ["AroAdm"]

grid_dict = {
    "model_type": [model_type],
    "architecture": ["MLP"],
    "m_set": ["SNP", "all"],
    "traits": trait_lists,
    "part": folds,
    "input_type": ["single-input", "multi-input"],
    "output_type": [output_type]
}

grid = expand_grid(grid_dict)

# No multi-input with SNP kernel case
grid = grid[~ ((grid.input_type == "multi-input") & (grid.m_set == "SNP"))]
print(grid)

grid.to_csv(os.path.join("parameters", out_name), index = False)
# Out:
#    model_type architecture m_set  \
# 0       kerPC          MLP   SNP
# 2       kerPC          MLP   SNP
# 4       kerPC          MLP   SNP
# 6       kerPC          MLP   all
# 7       kerPC          MLP   all
# 8       kerPC          MLP   all
# 9       kerPC          MLP   all
# 10      kerPC          MLP   all
# 11      kerPC          MLP   all
#
#                                                traits    part    input_type  \
# 0      [culm.diameter.1st.internode, leaf.senescence]  AroAdm  single-input
# 2       [grain.weight, time.to.flowering.from.sowing]  AroAdm  single-input
# 4   [culm.diameter.1st.internode, leaf.senescence,...  AroAdm  single-input
# 6      [culm.diameter.1st.internode, leaf.senescence]  AroAdm  single-input
# 7      [culm.diameter.1st.internode, leaf.senescence]  AroAdm   multi-input
# 8       [grain.weight, time.to.flowering.from.sowing]  AroAdm  single-input
# 9       [grain.weight, time.to.flowering.from.sowing]  AroAdm   multi-input
# 10  [culm.diameter.1st.internode, leaf.senescence,...  AroAdm  single-input
# 11  [culm.diameter.1st.internode, leaf.senescence,...  AroAdm   multi-input
#
#      output_type
# 0   multi-output
# 2   multi-output
# 4   multi-output
# 6   multi-output
# 7   multi-output
# 8   multi-output
# 9   multi-output
# 10  multi-output
# 11  multi-output

# %%
# 10-fold-cv #############################################################################
out_name = f"10-fold-cv_{model_type}_{output_type}.csv"

folds = parts.columns.drop(["Accession", "AroAdm"]).to_list()

grid_dict = {
    "model_type": [model_type],
    "architecture": ["MLP"],
    "m_set": ["SNP", "all"],
    "traits": trait_lists,
    "part": folds,
    "input_type": ["single-input", "multi-input"],
    "output_type": [output_type]
}

grid = expand_grid(grid_dict)

# No multi-input with SNP kernel case
grid = grid[~ ((grid.input_type == "multi-input") & (grid.m_set == "SNP"))]
print(grid)

grid.to_csv(os.path.join("parameters", out_name), index = False)
# Out:
#     model_type architecture m_set  \
# 0        kerPC          MLP   SNP
# 2        kerPC          MLP   SNP
# 4        kerPC          MLP   SNP
# 6        kerPC          MLP   SNP
# 8        kerPC          MLP   SNP
# ..         ...          ...   ...
# 115      kerPC          MLP   all
# 116      kerPC          MLP   all
# 117      kerPC          MLP   all
# 118      kerPC          MLP   all
# 119      kerPC          MLP   all
#
#                                                 traits     part    input_type  \
# 0       [culm.diameter.1st.internode, leaf.senescence]   Fold.1  single-input
# 2       [culm.diameter.1st.internode, leaf.senescence]   Fold.2  single-input
# 4       [culm.diameter.1st.internode, leaf.senescence]   Fold.3  single-input
# 6       [culm.diameter.1st.internode, leaf.senescence]   Fold.4  single-input
# 8       [culm.diameter.1st.internode, leaf.senescence]   Fold.5  single-input
# ..                                                 ...      ...           ...
# 115  [culm.diameter.1st.internode, leaf.senescence,...   Fold.8   multi-input
# 116  [culm.diameter.1st.internode, leaf.senescence,...   Fold.9  single-input
# 117  [culm.diameter.1st.internode, leaf.senescence,...   Fold.9   multi-input
# 118  [culm.diameter.1st.internode, leaf.senescence,...  Fold.10  single-input
# 119  [culm.diameter.1st.internode, leaf.senescence,...  Fold.10   multi-input
#
#       output_type
# 0    multi-output
# 2    multi-output
# 4    multi-output
# 6    multi-output
# 8    multi-output
# ..            ...
# 115  multi-output
# 116  multi-output
# 117  multi-output
# 118  multi-output
# 119  multi-output
#
# [90 rows x 7 columns]
