# %%
import os
import ast

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
plt.style.use("seaborn-whitegrid")
import seaborn as sns
sns.set_style("whitegrid")

# %%
# 1. Obtain parameters for the different analyses ----------------------------------------

par_file_list = [
    "10-fold-cv_kerPC.csv",
    "10-fold-cv_kerPC_multi-output.csv",
    "10-fold-cv_top-markers-10k.csv",
    "10-fold-cv_top-markers-10k_multi-input_multi-output.csv",
    "AroAdm_kerPC.csv",
    "AroAdm_kerPC_multi-output.csv",
    "AroAdm_top-markers-10k.csv",
    "AroAdm_top-markers-10k_multi-input_multi-output.csv"
]

# par_file_list = [
#     "10-fold-cv_kerPC.csv"
# ]

# %%
# Final dataframe
RES = pd.DataFrame()

# For each parameters (experiment) file
for par_file in par_file_list:
    
    # Load grid
    par_grid = pd.read_csv(os.path.join("parameters", par_file))

    # For each row of grid (each analysis)
    for row_number in range(par_grid.shape[0]):
        
        # Extract parameters =====================================================================

        # Which row of the grid
        pars = par_grid.iloc[row_number]
        # print(pars, "\n")

        # Model type: top-markers-10k or kerPC
        model_type = pars["model_type"]

        # Common pars
        architecture = pars["architecture"]
        m_set = pars["m_set"]
        traits = pars["traits"]
        part = pars["part"]
        input_type = pars["input_type"]
        output_type = pars["output_type"]

        # Output folder
        out_folder = os.path.join("models", f"{model_type}_{architecture}_{m_set}_{input_type}", traits, part)
        if not os.path.isdir(out_folder):
            os.makedirs(out_folder)
        print(out_folder)

        # Save traits as list
        # If multi-output, change literal string to list
        if output_type == "multi-output":
            traits = ast.literal_eval(traits)
        else:
            traits = [traits]
        # print(traits)

        # Target variable type
        # Save as list, just like traits
        target_dict = {
            "culm.diameter.1st.internode": "binary",
            "leaf.senescence": "binary",
            "grain.weight": "continuous",
            "time.to.flowering.from.sowing": "continuous"
        }

        target_types = []
        for trait_i in traits:
            if trait_i not in target_dict.keys():
                print("Define variable type of the target in the dictionary")
                exit(1)
            target_types.append(target_dict[trait_i])

        # print(target_types)
        
        # 2. Get prediction results ------------------------------------------------------

        # Which partition was used for Hpar optimization
        # which_hps = part
        which_hps = "AroAdm"
        # print(which_hps)

        # Path of prediction results
        pred_path = os.path.join(out_folder, f"results_hps_{which_hps}")
        # print(pred_path)

        # Prediction in case we wanted it
        # for i in range(len(traits)):
        #     prediction_path = os.path.join(pred_path, f"prediction_{traits[i]}.csv")
        #     prediction = pd.read_csv(prediction_path)
        
        # Results file
        res_path = os.path.join(pred_path, "results.csv")
        res = pd.read_csv(res_path, index_col = 0)
        res = res["mean"].to_frame().T.reset_index(drop = True)
        
        # Experiment parameters
        pars_tmp = pars.to_frame().T.reset_index(drop = True)
        
        # Join experiment pars and results
        res_tmp = pd.concat([pars_tmp, res], axis = 1)
        
        # Row bind to final dataframe
        RES = pd.concat([RES, res_tmp], ignore_index = True, sort = False)
# Out:
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.1
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.2
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.3
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.4
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.5
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.6
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.7
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.8
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.9
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.10
# models/kerPC_MLP_SNP_single-input/leaf.senescence/Fold.1
# models/kerPC_MLP_SNP_single-input/leaf.senescence/Fold.2
# models/kerPC_MLP_SNP_single-input/leaf.senescence/Fold.3
# models/kerPC_MLP_SNP_single-input/leaf.senescence/Fold.4
# models/kerPC_MLP_SNP_single-input/leaf.senescence/Fold.5
# models/kerPC_MLP_SNP_single-input/leaf.senescence/Fold.6
# models/kerPC_MLP_SNP_single-input/leaf.senescence/Fold.7
# models/kerPC_MLP_SNP_single-input/leaf.senescence/Fold.8
# models/kerPC_MLP_SNP_single-input/leaf.senescence/Fold.9
# models/kerPC_MLP_SNP_single-input/leaf.senescence/Fold.10
# models/kerPC_MLP_SNP_single-input/grain.weight/Fold.1
# models/kerPC_MLP_SNP_single-input/grain.weight/Fold.2
# models/kerPC_MLP_SNP_single-input/grain.weight/Fold.3
# models/kerPC_MLP_SNP_single-input/grain.weight/Fold.4
# models/kerPC_MLP_SNP_single-input/grain.weight/Fold.5
# models/kerPC_MLP_SNP_single-input/grain.weight/Fold.6
# models/kerPC_MLP_SNP_single-input/grain.weight/Fold.7
# models/kerPC_MLP_SNP_single-input/grain.weight/Fold.8
# models/kerPC_MLP_SNP_single-input/grain.weight/Fold.9
# models/kerPC_MLP_SNP_single-input/grain.weight/Fold.10
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.1
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.2
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.3
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.4
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.5
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.6
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.7
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.8
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.9
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.10
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/Fold.1
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/Fold.1
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/Fold.2
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/Fold.2
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/Fold.3
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/Fold.3
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/Fold.4
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/Fold.4
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/Fold.5
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/Fold.5
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/Fold.6
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/Fold.6
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/Fold.7
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/Fold.7
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/Fold.8
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/Fold.8
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/Fold.9
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/Fold.9
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/Fold.10
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/Fold.10
# models/kerPC_MLP_all_single-input/leaf.senescence/Fold.1
# models/kerPC_MLP_all_multi-input/leaf.senescence/Fold.1
# models/kerPC_MLP_all_single-input/leaf.senescence/Fold.2
# models/kerPC_MLP_all_multi-input/leaf.senescence/Fold.2
# models/kerPC_MLP_all_single-input/leaf.senescence/Fold.3
# models/kerPC_MLP_all_multi-input/leaf.senescence/Fold.3
# models/kerPC_MLP_all_single-input/leaf.senescence/Fold.4
# models/kerPC_MLP_all_multi-input/leaf.senescence/Fold.4
# models/kerPC_MLP_all_single-input/leaf.senescence/Fold.5
# models/kerPC_MLP_all_multi-input/leaf.senescence/Fold.5
# models/kerPC_MLP_all_single-input/leaf.senescence/Fold.6
# models/kerPC_MLP_all_multi-input/leaf.senescence/Fold.6
# models/kerPC_MLP_all_single-input/leaf.senescence/Fold.7
# models/kerPC_MLP_all_multi-input/leaf.senescence/Fold.7
# models/kerPC_MLP_all_single-input/leaf.senescence/Fold.8
# models/kerPC_MLP_all_multi-input/leaf.senescence/Fold.8
# models/kerPC_MLP_all_single-input/leaf.senescence/Fold.9
# models/kerPC_MLP_all_multi-input/leaf.senescence/Fold.9
# models/kerPC_MLP_all_single-input/leaf.senescence/Fold.10
# models/kerPC_MLP_all_multi-input/leaf.senescence/Fold.10
# models/kerPC_MLP_all_single-input/grain.weight/Fold.1
# models/kerPC_MLP_all_multi-input/grain.weight/Fold.1
# models/kerPC_MLP_all_single-input/grain.weight/Fold.2
# models/kerPC_MLP_all_multi-input/grain.weight/Fold.2
# models/kerPC_MLP_all_single-input/grain.weight/Fold.3
# models/kerPC_MLP_all_multi-input/grain.weight/Fold.3
# models/kerPC_MLP_all_single-input/grain.weight/Fold.4
# models/kerPC_MLP_all_multi-input/grain.weight/Fold.4
# models/kerPC_MLP_all_single-input/grain.weight/Fold.5
# models/kerPC_MLP_all_multi-input/grain.weight/Fold.5
# models/kerPC_MLP_all_single-input/grain.weight/Fold.6
# models/kerPC_MLP_all_multi-input/grain.weight/Fold.6
# models/kerPC_MLP_all_single-input/grain.weight/Fold.7
# models/kerPC_MLP_all_multi-input/grain.weight/Fold.7
# models/kerPC_MLP_all_single-input/grain.weight/Fold.8
# models/kerPC_MLP_all_multi-input/grain.weight/Fold.8
# models/kerPC_MLP_all_single-input/grain.weight/Fold.9
# models/kerPC_MLP_all_multi-input/grain.weight/Fold.9
# models/kerPC_MLP_all_single-input/grain.weight/Fold.10
# models/kerPC_MLP_all_multi-input/grain.weight/Fold.10
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/Fold.1
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/Fold.1
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/Fold.2
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/Fold.2
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/Fold.3
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/Fold.3
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/Fold.4
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/Fold.4
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/Fold.5
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/Fold.5
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/Fold.6
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/Fold.6
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/Fold.7
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/Fold.7
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/Fold.8
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/Fold.8
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/Fold.9
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/Fold.9
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/Fold.10
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/Fold.10
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.1
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.2
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.3
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.4
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.5
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.6
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.7
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.8
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.9
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.10
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.1
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.2
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.3
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.4
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.5
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.6
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.7
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.8
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.9
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.10
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.1
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.2
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.3
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.4
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.5
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.6
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.7
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.8
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.9
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.10
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.1
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.1
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.2
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.2
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.3
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.3
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.4
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.4
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.5
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.5
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.6
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.6
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.7
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.7
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.8
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.8
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.9
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.9
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.10
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.10
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.1
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.1
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.2
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.2
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.3
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.3
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.4
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.4
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.5
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.5
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.6
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.6
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.7
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.7
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.8
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.8
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.9
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.9
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.10
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.10
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.1
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.1
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.2
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.2
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.3
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.3
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.4
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.4
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.5
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.5
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.6
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.6
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.7
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.7
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.8
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.8
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.9
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.9
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.10
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.10
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.1
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.2
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.3
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.4
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.5
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.6
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.7
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.8
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.9
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/Fold.10
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/Fold.1
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/Fold.2
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/Fold.3
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/Fold.4
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/Fold.5
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/Fold.6
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/Fold.7
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/Fold.8
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/Fold.9
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/Fold.10
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/Fold.1
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/Fold.2
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/Fold.3
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/Fold.4
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/Fold.5
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/Fold.6
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/Fold.7
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/Fold.8
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/Fold.9
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/Fold.10
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.1
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.2
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.3
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.4
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.5
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.6
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.7
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.8
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.9
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/Fold.10
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/Fold.1
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/Fold.2
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/Fold.3
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/Fold.4
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/Fold.5
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/Fold.6
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/Fold.7
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/Fold.8
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/Fold.9
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/Fold.10
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/Fold.1
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/Fold.2
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/Fold.3
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/Fold.4
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/Fold.5
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/Fold.6
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/Fold.7
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/Fold.8
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/Fold.9
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/Fold.10
# models/top-markers-10k_MLP_all_single-input/grain.weight/Fold.1
# models/top-markers-10k_MLP_all_single-input/grain.weight/Fold.2
# models/top-markers-10k_MLP_all_single-input/grain.weight/Fold.3
# models/top-markers-10k_MLP_all_single-input/grain.weight/Fold.4
# models/top-markers-10k_MLP_all_single-input/grain.weight/Fold.5
# models/top-markers-10k_MLP_all_single-input/grain.weight/Fold.6
# models/top-markers-10k_MLP_all_single-input/grain.weight/Fold.7
# models/top-markers-10k_MLP_all_single-input/grain.weight/Fold.8
# models/top-markers-10k_MLP_all_single-input/grain.weight/Fold.9
# models/top-markers-10k_MLP_all_single-input/grain.weight/Fold.10
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/Fold.1
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/Fold.2
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/Fold.3
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/Fold.4
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/Fold.5
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/Fold.6
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/Fold.7
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/Fold.8
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/Fold.9
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/Fold.10
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/Fold.1
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/Fold.2
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/Fold.3
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/Fold.4
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/Fold.5
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/Fold.6
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/Fold.7
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/Fold.8
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/Fold.9
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/Fold.10
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/Fold.1
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/Fold.2
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/Fold.3
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/Fold.4
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/Fold.5
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/Fold.6
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/Fold.7
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/Fold.8
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/Fold.9
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/Fold.10
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/Fold.1
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/Fold.2
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/Fold.3
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/Fold.4
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/Fold.5
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/Fold.6
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/Fold.7
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/Fold.8
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/Fold.9
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/Fold.10
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/Fold.1
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/Fold.2
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/Fold.3
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/Fold.4
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/Fold.5
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/Fold.6
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/Fold.7
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/Fold.8
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/Fold.9
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/Fold.10
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/Fold.1
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/Fold.2
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/Fold.3
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/Fold.4
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/Fold.5
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/Fold.6
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/Fold.7
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/Fold.8
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/Fold.9
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/Fold.10
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/Fold.1
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/Fold.2
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/Fold.3
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/Fold.4
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/Fold.5
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/Fold.6
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/Fold.7
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/Fold.8
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/Fold.9
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/Fold.10
# models/top-markers-10k_CNN_all_single-input/grain.weight/Fold.1
# models/top-markers-10k_CNN_all_single-input/grain.weight/Fold.2
# models/top-markers-10k_CNN_all_single-input/grain.weight/Fold.3
# models/top-markers-10k_CNN_all_single-input/grain.weight/Fold.4
# models/top-markers-10k_CNN_all_single-input/grain.weight/Fold.5
# models/top-markers-10k_CNN_all_single-input/grain.weight/Fold.6
# models/top-markers-10k_CNN_all_single-input/grain.weight/Fold.7
# models/top-markers-10k_CNN_all_single-input/grain.weight/Fold.8
# models/top-markers-10k_CNN_all_single-input/grain.weight/Fold.9
# models/top-markers-10k_CNN_all_single-input/grain.weight/Fold.10
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/Fold.1
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/Fold.2
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/Fold.3
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/Fold.4
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/Fold.5
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/Fold.6
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/Fold.7
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/Fold.8
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/Fold.9
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/Fold.10
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.1
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.2
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.3
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.4
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.5
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.6
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.7
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.8
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.9
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.10
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.1
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.2
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.3
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.4
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.5
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.6
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.7
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.8
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.9
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.10
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.1
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.2
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.3
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.4
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.5
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.6
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.7
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.8
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.9
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.10
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.1
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.2
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.3
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.4
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.5
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.6
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.7
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.8
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.9
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/Fold.10
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.1
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.2
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.3
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.4
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.5
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.6
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.7
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.8
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.9
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/Fold.10
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.1
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.2
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.3
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.4
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.5
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.6
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.7
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.8
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.9
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/Fold.10
# models/kerPC_MLP_SNP_single-input/culm.diameter.1st.internode/AroAdm
# models/kerPC_MLP_SNP_single-input/leaf.senescence/AroAdm
# models/kerPC_MLP_SNP_single-input/grain.weight/AroAdm
# models/kerPC_MLP_SNP_single-input/time.to.flowering.from.sowing/AroAdm
# models/kerPC_MLP_all_single-input/culm.diameter.1st.internode/AroAdm
# models/kerPC_MLP_all_multi-input/culm.diameter.1st.internode/AroAdm
# models/kerPC_MLP_all_single-input/leaf.senescence/AroAdm
# models/kerPC_MLP_all_multi-input/leaf.senescence/AroAdm
# models/kerPC_MLP_all_single-input/grain.weight/AroAdm
# models/kerPC_MLP_all_multi-input/grain.weight/AroAdm
# models/kerPC_MLP_all_single-input/time.to.flowering.from.sowing/AroAdm
# models/kerPC_MLP_all_multi-input/time.to.flowering.from.sowing/AroAdm
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/AroAdm
# models/kerPC_MLP_SNP_single-input/['grain.weight', 'time.to.flowering.from.sowing']/AroAdm
# models/kerPC_MLP_SNP_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/AroAdm
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence']/AroAdm
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/AroAdm
# models/kerPC_MLP_all_single-input/['grain.weight', 'time.to.flowering.from.sowing']/AroAdm
# models/kerPC_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/AroAdm
# models/kerPC_MLP_all_single-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/AroAdm
# models/kerPC_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/AroAdm
# models/top-markers-10k_MLP_SNP_single-input/culm.diameter.1st.internode/AroAdm
# models/top-markers-10k_MLP_SNP_single-input/leaf.senescence/AroAdm
# models/top-markers-10k_MLP_SNP_single-input/grain.weight/AroAdm
# models/top-markers-10k_MLP_SNP_single-input/time.to.flowering.from.sowing/AroAdm
# models/top-markers-10k_MLP_all_single-input/culm.diameter.1st.internode/AroAdm
# models/top-markers-10k_MLP_all_single-input/leaf.senescence/AroAdm
# models/top-markers-10k_MLP_all_single-input/grain.weight/AroAdm
# models/top-markers-10k_MLP_all_single-input/time.to.flowering.from.sowing/AroAdm
# models/top-markers-10k_CNN_SNP_single-input/culm.diameter.1st.internode/AroAdm
# models/top-markers-10k_CNN_SNP_single-input/leaf.senescence/AroAdm
# models/top-markers-10k_CNN_SNP_single-input/grain.weight/AroAdm
# models/top-markers-10k_CNN_SNP_single-input/time.to.flowering.from.sowing/AroAdm
# models/top-markers-10k_CNN_all_single-input/culm.diameter.1st.internode/AroAdm
# models/top-markers-10k_CNN_all_single-input/leaf.senescence/AroAdm
# models/top-markers-10k_CNN_all_single-input/grain.weight/AroAdm
# models/top-markers-10k_CNN_all_single-input/time.to.flowering.from.sowing/AroAdm
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/AroAdm
# models/top-markers-10k_MLP_SNP_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/AroAdm
# models/top-markers-10k_MLP_SNP_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/AroAdm
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence']/AroAdm
# models/top-markers-10k_MLP_all_multi-input/['grain.weight', 'time.to.flowering.from.sowing']/AroAdm
# models/top-markers-10k_MLP_all_multi-input/['culm.diameter.1st.internode', 'leaf.senescence', 'grain.weight', 'time.to.flowering.from.sowing']/AroAdm

# %%
RES
# Out:
#           model_type architecture m_set  \
# 0              kerPC          MLP   SNP
# 1              kerPC          MLP   SNP
# 2              kerPC          MLP   SNP
# 3              kerPC          MLP   SNP
# 4              kerPC          MLP   SNP
# ..               ...          ...   ...
# 468  top-markers-10k          MLP   SNP
# 469  top-markers-10k          MLP   SNP
# 470  top-markers-10k          MLP   all
# 471  top-markers-10k          MLP   all
# 472  top-markers-10k          MLP   all
#
#                                                 traits    part    input_type  \
# 0                          culm.diameter.1st.internode  Fold.1  single-input
# 1                          culm.diameter.1st.internode  Fold.2  single-input
# 2                          culm.diameter.1st.internode  Fold.3  single-input
# 3                          culm.diameter.1st.internode  Fold.4  single-input
# 4                          culm.diameter.1st.internode  Fold.5  single-input
# ..                                                 ...     ...           ...
# 468  ['grain.weight', 'time.to.flowering.from.sowing']  AroAdm   multi-input
# 469  ['culm.diameter.1st.internode', 'leaf.senescen...  AroAdm   multi-input
# 470  ['culm.diameter.1st.internode', 'leaf.senescen...  AroAdm   multi-input
# 471  ['grain.weight', 'time.to.flowering.from.sowing']  AroAdm   multi-input
# 472  ['culm.diameter.1st.internode', 'leaf.senescen...  AroAdm   multi-input
#
#        output_type      loss  binary_crossentropy  accuracy  ...  \
# 0    single-output  0.698144             0.698144  0.516923  ...
# 1    single-output  0.677241             0.677241  0.571429  ...
# 2    single-output  0.697887             0.697887  0.542857  ...
# 3    single-output  0.702357             0.702357  0.535484  ...
# 4    single-output  0.670584             0.670584  0.574194  ...
# ..             ...       ...                  ...       ...  ...
# 468   multi-output  0.436573                  NaN       NaN  ...
# 469   multi-output  2.424227                  NaN       NaN  ...
# 470   multi-output  1.790817                  NaN       NaN  ...
# 471   multi-output  0.441500                  NaN       NaN  ...
# 472   multi-output  3.361067                  NaN       NaN  ...
#
#      culm.diameter.1st.internode_loss  leaf.senescence_loss  \
# 0                                 NaN                   NaN
# 1                                 NaN                   NaN
# 2                                 NaN                   NaN
# 3                                 NaN                   NaN
# 4                                 NaN                   NaN
# ..                                ...                   ...
# 468                               NaN                   NaN
# 469                          0.737777              0.704310
# 470                          0.981841              0.808976
# 471                               NaN                   NaN
# 472                          0.775800              0.714694
#
#      culm.diameter.1st.internode_binary_crossentropy  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 468                                              NaN
# 469                                         0.737777
# 470                                         0.981841
# 471                                              NaN
# 472                                         0.775800
#
#      culm.diameter.1st.internode_accuracy  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 468                                   NaN
# 469                               0.62500
# 470                               0.51250
# 471                                   NaN
# 472                               0.61875
#
#      leaf.senescence_binary_crossentropy  leaf.senescence_accuracy  \
# 0                                    NaN                       NaN
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                    NaN                       NaN
# ..                                   ...                       ...
# 468                                  NaN                       NaN
# 469                             0.704310                   0.58125
# 470                             0.808976                   0.70625
# 471                                  NaN                       NaN
# 472                             0.714694                   0.66875
#
#      grain.weight_loss  time.to.flowering.from.sowing_loss  grain.weight_mse  \
# 0                  NaN                                 NaN               NaN
# 1                  NaN                                 NaN               NaN
# 2                  NaN                                 NaN               NaN
# 3                  NaN                                 NaN               NaN
# 4                  NaN                                 NaN               NaN
# ..                 ...                                 ...               ...
# 468           0.384849                            0.051724          0.384849
# 469           0.353837                            0.628303          0.353837
# 470                NaN                                 NaN               NaN
# 471           0.385789                            0.055712          0.385789
# 472           0.313644                            1.556929          0.313644
#
#      time.to.flowering.from.sowing_mse
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 468                           0.051724
# 469                           0.628303
# 470                                NaN
# 471                           0.055712
# 472                           1.556929
#
# [473 rows x 28 columns]

# %%
# Save results

final_path = os.path.join("final_results")
if not os.path.isdir(final_path):
    os.mkdir(final_path)

RES.to_csv(os.path.join(final_path, "final_results.csv"), index = False)
